# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Juan Camilo Ruiz Salazar**
#
# Coordinador observatorio prácticas lectoras Biblored

# %% [markdown]
# *I´m intersted in develop best practices in the use of data ascience in the observatory of reading practices on BilbloRed*

# %% [markdown]
# ### In the fifth row i want to make a multiplication with two numbers given by the user

# %%
A=int(input("enter first number"))
B=int(input("enter second number"))
print("the result is:")
A*B
# Out:
# enter first number2
# enter second number3
# the result is:
# 6

# %% [markdown]
# 1. First item
# 1. Second item
#     1. First item of the near one
#     1. Second item of the near one
# - Item  bulleted
# > Blokquotes here
#
# Bulding a ~~strikethtough~~
#
# __[Link to Dockduckgo].(https://duckduckgo.com)__
#
# |Col1|Col2|Col3|
# |----|----|----|
# |Cas1|Ca12|Ca13|
# |Cas2|Ca22|Ca23|
# |Cas3|Ca32|Ca33|
#
# ![IMG_1789.jpeg](attachment:IMG_1789.jpeg)
